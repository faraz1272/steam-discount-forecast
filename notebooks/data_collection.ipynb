# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import os
from dotenv import load_dotenv

from datetime import datetime, timezone

import os, time, math, json, sqlite3, requests
from datetime import datetime, timezone
from typing import List
from contextlib import closing

# %%
STEAM_APP_ID = 812140  # Example: Assassin's Creed Odyssey

# %% [markdown]
# #### Loading data from ITAD API

# %%
load_dotenv()
ITAD_API_KEY = os.getenv('ITAD_API_KEY')
if not ITAD_API_KEY:
    raise ValueError("Please set the ITAD_API_KEY environment variable.")

# %%
url_appID = "https://api.isthereanydeal.com/lookup/id/shop/61/v1"

payload = [f"app/{STEAM_APP_ID}"] # this API accepts a list of identifiers

headers = {
    "Authorization": f"key {ITAD_API_KEY}",
    "Content-Type": "application/json"
}

# %%
try:
    resp = requests.post(url_appID, headers=headers, json=payload, timeout=15)
    resp.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print("HTTP error:", http_err, "| Body:", getattr(resp, "text", ""))
except requests.exceptions.RequestException as req_err:
    print("Request error:", req_err)
else:
    game_id = resp.json()
    print("Raw JSON:", resp.json())
# Out:
# Raw JSON: {'app/812140': '018d937f-0184-7248-8d64-3c723c523111'}

# %%
ITAD_GAME_ID = game_id['app/812140']
print("ITAD Game ID:", ITAD_GAME_ID)
# Out:
# ITAD Game ID: 018d937f-0184-7248-8d64-3c723c523111

# %%
url_info = f"https://api.isthereanydeal.com/games/info/v2"

params2 = {"id": ITAD_GAME_ID, "key": ITAD_API_KEY}

# %%
try:
    r = requests.get(url_info, params=params2, timeout=15)
    r.raise_for_status()
    info = r.json()
    print("Game title:", info.get("title"))
    print("Tags:", info.get("tags"))
    print("Release date:", info.get("releaseDate"))
    print("Publisher:", info.get("publishers"))
    print("Players:", info.get("players"))
    print("Reviews:", info.get("reviews"))
except requests.HTTPError as e:
    print("HTTP error:", e, "| Body:", r.text)
# Out:
# Game title: Assassin's Creed Odyssey
# Tags: ['Open World', 'RPG', 'Singleplayer', 'Historical', 'Action']
# Release date: 2018-10-03
# Publisher: [{'id': 61, 'name': 'Ubisoft'}]
# Players: {'recent': 9400, 'day': 10837, 'week': 10837, 'peak': 61984}
# Reviews: [{'score': 89, 'source': 'Steam', 'count': 158914, 'url': 'https://store.steampowered.com/app/812140/'}, {'score': 86, 'source': 'Metascore', 'count': 14, 'url': 'https://metacritic.com/game/assassins-creed-odyssey/critic-reviews/?platform=pc'}, {'score': 69, 'source': 'Metacritic User Score', 'count': 5304, 'url': 'https://metacritic.com/game/assassins-creed-odyssey/user-reviews/?platform=pc'}, {'score': 84, 'source': 'OpenCritic', 'count': 169, 'url': 'https://opencritic.com/game/6222/assassins-creed-odyssey'}]

# %%
url_history = "https://api.isthereanydeal.com/games/history/v2"

params = {
    "key": ITAD_API_KEY,
    "id": ITAD_GAME_ID,
    "country": "us",
    "shops": "61",
    "since": "2018-01-01T00:00:00Z"
}

# %%
try:
    r = requests.get(url_history, params=params, timeout=15)
    print("Request URL:", r.url)
    r.raise_for_status()
    history = r.json()
    print("Price history data:", history)
except requests.HTTPError as e:
    print("HTTP error:", e, "| Body:", r.text)
except requests.RequestException as e:
    print("Request error:", e)
# Out:
# Request URL: https://api.isthereanydeal.com/games/history/v2?key=6e83d100e0379ecd168d625928bec6a244dd08d4&id=018d937f-0184-7248-8d64-3c723c523111&country=us&shops=61&since=2018-01-01T00%3A00%3A00Z
# ...

# %%
from datetime import datetime, timezone
from typing import List, Dict, Optional

def _parse_ts(ts: str) -> datetime:
    # handles both ...Z and timezone offsets like +02:00; returns UTC
    dt = datetime.fromisoformat(ts.replace("Z", "+00:00"))
    return dt.astimezone(timezone.utc)

def _dedupe_same_timestamp(events: List[Dict]) -> List[Dict]:
    """
    For events sharing the same timestamp, keep the one with the largest cut.
    This avoids double-logs from scraper updates at identical times.
    """
    bucket = {}
    for e in events:
        t = e["timestamp"]
        cut = (e.get("deal") or {}).get("cut") or 0
        if (t not in bucket) or (cut > ((bucket[t].get("deal") or {}).get("cut") or 0)):
            bucket[t] = e
    return [bucket[t] for t in sorted(bucket.keys(), key=_parse_ts)]

def find_first_sale(
    history: List[Dict],
    release_dt: Optional[datetime] = None,
    min_cut: int = 5,
    post_launch_only: bool = True,
) -> Optional[Dict]:
    """
    history: full list from ITAD /games/history/v2 (already filtered to shop=61, country fixed)
    release_dt: UTC datetime (from /games/info/v2). If None, no pre-release filtering is applied.
    min_cut: minimum % discount to consider a sale
    post_launch_only: ignore events strictly before release_dt if True
    returns dict with keys: timestamp (UTC dt), cut, price, regular  OR None if no sale
    """
    if not history:
        return None

    # normalize + sort
    events_sorted = sorted(history, key=lambda e: _parse_ts(e["timestamp"]))
    # dedupe by identical timestamp (keep max cut)
    events_sorted = _dedupe_same_timestamp(events_sorted)

    for e in events_sorted:
        ts = _parse_ts(e["timestamp"])
        if post_launch_only and release_dt is not None and ts < release_dt:
            continue

        deal = e.get("deal") or {}
        cut = deal.get("cut") or 0
        price = (deal.get("price") or {}).get("amount")
        regular = (deal.get("regular") or {}).get("amount")

        # sanity checks for a true sale
        if cut >= min_cut and price is not None and regular is not None and price < regular:
            return {
                "timestamp": ts,
                "cut": int(cut),
                "price": float(price),
                "regular": float(regular),
            }

    return None

def days_between(a: datetime, b: datetime) -> int:
    return (b - a).days

# %%
# 1) get release date (UTC) from /games/info/v2
release_iso = info.get("releaseDate")  # e.g., "2025-08-20T00:00:00Z"
release_dt = datetime.fromisoformat(release_iso.replace("Z", "+00:00")).astimezone(timezone.utc)

# 2) get full history list from /games/history/v2 (shop=61, country consistent)
events = history if isinstance(history, list) else history.get("history", [])

# 3) compute label
first_sale = find_first_sale(events, release_dt=release_dt, min_cut=5, post_launch_only=True)

if first_sale:
    label_days = days_between(release_dt, first_sale["timestamp"])
    print({
        "first_sale_date": first_sale["timestamp"].date().isoformat(),
        "first_sale_cut": first_sale["cut"],
        "first_sale_price": first_sale["price"],
        "first_sale_regular": first_sale["regular"],
        "days_to_first_sale": label_days,
    })
else:
    print({"first_sale_date": None, "days_to_first_sale": None, "censored": True})
# Out:
# {'first_sale_date': '2018-11-21', 'first_sale_cut': 33, 'first_sale_price': 40.19, 'first_sale_regular': 59.99, 'days_to_first_sale': 49}

# %%
kaggle_data = pd.read_csv("Kaggle datasets/93182_steam_games.csv")
kaggle_data.head()
# Out:
# /var/folders/1f/b537t8w54jj9x40zq_pnqq4c0000gn/T/ipykernel_47894/4040152700.py:1: DtypeWarning: Columns (3,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   kaggle_data = pd.read_csv("Kaggle datasets/93182_steam_games.csv")
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0  1424640                     余烬   Oct 3, 2020    20000 - 50000         0
# 1   402890            Nyctophilia  Sep 23, 2015   50000 - 100000         0
# 2  1151740        Prison Princess   Apr 2, 2020        0 - 20000         0
# 3   875530           Dead In Time  Oct 12, 2018        0 - 20000         0
# 4  1835360  Panacle: Back To Wild  Mar 11, 2022        0 - 20000         2
#
#    Required age  Price  DLC count  \
# 0             0   3.99          0
# 1             0   0.00          0
# 2             0  19.99          0
# 3             0   7.99          0
# 4             0   3.99          0
#
# ...

# %%
kaggle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93182 entries, 0 to 93181
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AppID                       93182 non-null  int64
#  1   Name                        93179 non-null  object
#  2   Release date                93182 non-null  object
#  3   Estimated owners            16462 non-null  object
#  4   Peak CCU                    93182 non-null  int64
#  5   Required age                93182 non-null  int64
#  6   Price                       93182 non-null  float64
#  7   DLC count                   93182 non-null  int64
#  8   About the game              88392 non-null  object
#  9   Supported languages         93182 non-null  object
#  10  Full audio languages        93182 non-null  object
#  11  Reviews                     10599 non-null  object
#  12  Header image                93182 non-null  object
# ...

# %%
kaggle_data['AppID'].nunique()
# Out:
# 93182

# %%
kaggle_data["Release date"] = pd.to_datetime(kaggle_data["Release date"], format="%b %d, %Y", errors="coerce")

# %%
kaggle_data.head()
# Out:
#      AppID                   Name Release date Estimated owners  Peak CCU  \
# 0  1424640                     余烬   2020-10-03    20000 - 50000         0
# 1   402890            Nyctophilia   2015-09-23   50000 - 100000         0
# 2  1151740        Prison Princess   2020-04-02        0 - 20000         0
# 3   875530           Dead In Time   2018-10-12        0 - 20000         0
# 4  1835360  Panacle: Back To Wild   2022-03-11        0 - 20000         2
#
#    Required age  Price  DLC count  \
# 0             0   3.99          0
# 1             0   0.00          0
# 2             0  19.99          0
# 3             0   7.99          0
# 4             0   3.99          0
#
#                                       About the game  \
# 0  'Ashes of war' is an anti war theme adventure ...
# 1  NYCTOPHILIA Nyctophilia is an 2D psychological...
# 2  ABOUT Now nothing more than a phantom, can the...
# 3  Is a hardcore action with a non-trivial level ...
# ...

# %%
kaggle_data[(kaggle_data['Release date'] > '2021-01-01') & (kaggle_data['Release date'] < '2024-12-31')]
# Out:
#          AppID                                   Name Release date  \
# 4      1835360                  Panacle: Back To Wild   2022-03-11
# 7      2604580                            THE JUSOU 3   2024-02-20
# 12     2261280                            WHITE WATER   2023-01-16
# 13     2325490                      Minamochi Factory   2023-06-22
# 15     2214650                         Rolando Deluxe   2024-04-17
# ...        ...                                    ...          ...
# 93176  2452810  Alien IQ Exam: Human Edition, Phase 1   2023-07-06
# 93177  2251030        Mutant Monty (C64/CPC/Spectrum)   2023-01-05
# 93179  1844230                      Malicious ReloadⅡ   2023-09-05
# 93180  2623690                            Mutant Frog   2024-01-27
# 93181  2313950                              CRAZY GUY   2023-03-20
#
#       Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 4            0 - 20000         2             0   3.99          0
# ...

# %% [markdown]
# ### I am grabbing all the Steam AppIDs from the 2021 upto 2024

# %%
filtered = kaggle_data[(kaggle_data['Release date'] > '2021-01-01') &
                       (kaggle_data['Release date'] < '2024-12-31')]

appids = filtered['AppID'].dropna().astype(int).drop_duplicates().tolist()

# %% [markdown]
# ### Building the database in SQL Lite

# %%
ITAD_API_KEY = os.getenv("ITAD_API_KEY")  # or paste your key here temporarily
assert ITAD_API_KEY, "Set ITAD_API_KEY in your environment (e.g., .env)!"

DB_PATH = "data/steam_sales.db"
ITAD_LOOKUP_URL = "https://api.isthereanydeal.com/lookup/id/shop/61/v1"  # 61 = Steam

def utcnow_iso():
    return datetime.now(timezone.utc).isoformat().replace("+00:00","Z")

def get_conn(path=DB_PATH):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    conn = sqlite3.connect(path)
    conn.execute("PRAGMA foreign_keys = ON;")
    conn.execute("PRAGMA journal_mode = WAL;")
    conn.execute("PRAGMA synchronous = NORMAL;")
    return conn

# %%
with get_conn() as conn:
    conn.execute("""
    CREATE TABLE IF NOT EXISTS seeds (
        appid      INTEGER PRIMARY KEY,
        itad_id    TEXT,
        status     TEXT,         -- 'mapped', 'not_found', 'error'
        updated_at TEXT
    );
    """)
    conn.commit()

# %%
def chunked(seq: List[int], size: int):
    for i in range(0, len(seq), size):
        yield seq[i:i+size]

def upsert_seed_rows(rows):
    """
    rows: list of dicts with keys: appid, itad_id, status, updated_at
    """
    with get_conn() as conn:
        conn.executemany("""
        INSERT INTO seeds (appid, itad_id, status, updated_at)
        VALUES (:appid, :itad_id, :status, :updated_at)
        ON CONFLICT(appid) DO UPDATE SET
            itad_id=excluded.itad_id,
            status=excluded.status,
            updated_at=excluded.updated_at;
        """, rows)
        conn.commit()

# %%
def lookup_itad_ids_for_appids(appids: List[int], api_key: str, retry=3, sleep_sec=1.2):
    """
    Calls POST /lookup/id/shop/61/v1 with body ["app/<id>", ...]
    Returns: dict mapping "app/<id>" -> itad_id (or None if not found)
    """
    body = [f"app/{a}" for a in appids]
    params = {"key": api_key}  # query-param auth (simple & works)
    
    for attempt in range(1, retry+1):
        try:
            r = requests.post(ITAD_LOOKUP_URL, params=params, json=body, timeout=20)
            # Helpful for debugging:
            # print("Status:", r.status_code, "Remaining:", r.headers.get("X-RateLimit-Remaining"))
            r.raise_for_status()
            data = r.json()
            # data example: {"app/570":"018d...","app/440":null,...}
            return data
        except requests.HTTPError as e:
            # Backoff on rate limits or transient errors
            if r is not None and r.status_code in (429, 500, 502, 503, 504):
                time.sleep(sleep_sec * attempt)
                continue
            raise
        finally:
            # gentle pacing to respect ~1 r/s recommendation
            time.sleep(sleep_sec)
    return {}

# %%
BATCH_SIZE = 40   # 25–50 is a good range
results_summary = {"mapped": 0, "not_found": 0}

for batch in chunked(appids, BATCH_SIZE):
    mapping = lookup_itad_ids_for_appids(batch, ITAD_API_KEY)
    now = utcnow_iso()
    rows = []

    # Build rows for SQLite
    for a in batch:
        key = f"app/{a}"
        val = mapping.get(key, None)
        if isinstance(val, str) and val.strip():
            rows.append({"appid": a, "itad_id": val, "status": "mapped", "updated_at": now})
            results_summary["mapped"] += 1
        else:
            rows.append({"appid": a, "itad_id": None, "status": "not_found", "updated_at": now})
            results_summary["not_found"] += 1

    upsert_seed_rows(rows)

print("Done. Summary:", results_summary)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[125], line 5
#       2 results_summary = {"mapped": 0, "not_found": 0}
#       4 for batch in chunked(appids, BATCH_SIZE):
# ----> 5     mapping = lookup_itad_ids_for_appids(batch, ITAD_API_KEY)
#       6     now = utcnow_iso()
#       7     rows = []
#
# Cell In[124], line 26, in lookup_itad_ids_for_appids(appids, api_key, retry, sleep_sec)
#      23         raise
#      24     finally:
#      25         # gentle pacing to respect ~1 r/s recommendation
# ---> 26         time.sleep(sleep_sec)
#      27 return {}
#
# KeyboardInterrupt:

# %%
import sqlite3, pandas as pd
conn = sqlite3.connect("data/steam_sales.db")

# What tables exist?
pd.read_sql("SELECT * FROM seeds;", conn)
# Out:
#         appid                               itad_id     status  \
# 0        8980  018d937f-1d1f-73fa-9019-5296f63a702f     mapped
# 1      261550  018d937f-2b82-710b-be7f-7324eaa1d8d5     mapped
# 2      269190  018d937f-1b14-70f7-ba7d-e0d4c3f425d5     mapped
# 3      280720  018d937f-0845-7221-bb7a-ef2f7b17c451     mapped
# 4      314430  018d937f-2a0e-70d6-ac76-ce759fc93de3     mapped
# ...       ...                                   ...        ...
# 7075  3168000                                  None  not_found
# 7076  3168050                                  None  not_found
# 7077  3171800                                  None  not_found
# 7078  3173490                                  None  not_found
# 7079  3183340                                  None  not_found
#
#                        updated_at
# 0     2025-09-14T20:57:18.186903Z
# 1     2025-09-14T20:58:46.695843Z
# 2     2025-09-14T20:59:59.492887Z
# 3     2025-09-14T20:58:13.268206Z
# ...

# %%
import sqlite3, pandas as pd
conn = sqlite3.connect("data/steam_sales.db")

done = set(pd.read_sql("SELECT appid FROM seeds;", conn)['appid'])
conn.close()

remaining = [a for a in appids if a not in done]
len(remaining), remaining[:10]  # count + sample
# Out:
# (46046,
#  [2476720,
#   2011080,
#   2228960,
#   1569550,
#   1681480,
#   1523420,
#   2622850,
#   1658830,
#   2363060,
#   2542050])

# %%
BATCH_SIZE = 40   # 25–50 is a good range
results_summary = {"mapped": 0, "not_found": 0}

for batch in chunked(remaining, BATCH_SIZE):
    mapping = lookup_itad_ids_for_appids(batch, ITAD_API_KEY)
    now = utcnow_iso()
    rows = []

    # Build rows for SQLite
    for a in batch:
        key = f"app/{a}"
        val = mapping.get(key, None)
        if isinstance(val, str) and val.strip():
            rows.append({"appid": a, "itad_id": val, "status": "mapped", "updated_at": now})
            results_summary["mapped"] += 1
        else:
            rows.append({"appid": a, "itad_id": None, "status": "not_found", "updated_at": now})
            results_summary["not_found"] += 1

    upsert_seed_rows(rows)

print("Done. Summary:", results_summary)
# Out:
# Done. Summary: {'mapped': 43306, 'not_found': 2740}

# %%
conn = sqlite3.connect("data/steam_sales.db")

pd.read_sql("SELECT * FROM seeds;", conn)
# Out:
#          appid                               itad_id     status  \
# 0         7800  018d937f-2eb7-7037-82d1-2fab5fddf3d4     mapped
# 1         8980  018d937f-1d1f-73fa-9019-5296f63a702f     mapped
# 2        11550  018d937f-35ee-7204-ad6c-ae2e2639119f     mapped
# 3        24880  018d937e-ffc5-7152-8d6f-33f59b72cdb4     mapped
# 4       226280  018d937f-4ef3-7168-994d-7968084ab1a0     mapped
# ...        ...                                   ...        ...
# 53121  3193740                                  None  not_found
# 53122  3194700                                  None  not_found
# 53123  3195690  0191aab8-da1b-7047-86be-bf0466fd99fc     mapped
# 53124  3196990                                  None  not_found
# 53125  3199580                                  None  not_found
#
#                         updated_at
# 0      2025-09-14T21:22:13.620948Z
# 1      2025-09-14T20:57:18.186903Z
# 2      2025-09-14T21:21:58.576307Z
# 3      2025-09-14T21:23:56.160025Z
# ...

# %%
DB_PATH = "data/steam_sales.db"

with closing(sqlite3.connect(DB_PATH)) as conn:
    conn.executescript("""
    PRAGMA foreign_keys = ON;

    CREATE TABLE IF NOT EXISTS games (
      itad_id      TEXT PRIMARY KEY,
      appid        INTEGER,
      title        TEXT,
      type         TEXT,
      release_date TEXT,     -- ISO date
      early_access INTEGER,  -- 0/1
      mature       INTEGER   -- 0/1
    );

    CREATE TABLE IF NOT EXISTS publishers (
      publisher_id INTEGER PRIMARY KEY,
      name         TEXT UNIQUE
    );
    CREATE TABLE IF NOT EXISTS game_publishers (
      itad_id TEXT,
      publisher_id INTEGER,
      PRIMARY KEY (itad_id, publisher_id),
      FOREIGN KEY (itad_id) REFERENCES games(itad_id) ON DELETE CASCADE,
      FOREIGN KEY (publisher_id) REFERENCES publishers(publisher_id) ON DELETE CASCADE
    );

    CREATE TABLE IF NOT EXISTS developers (
      developer_id INTEGER PRIMARY KEY,
      name         TEXT UNIQUE
    );
    CREATE TABLE IF NOT EXISTS game_developers (
      itad_id TEXT,
      developer_id INTEGER,
      PRIMARY KEY (itad_id, developer_id),
      FOREIGN KEY (itad_id) REFERENCES games(itad_id) ON DELETE CASCADE,
      FOREIGN KEY (developer_id) REFERENCES developers(developer_id) ON DELETE CASCADE
    );

    CREATE TABLE IF NOT EXISTS tags (
      tag_id INTEGER PRIMARY KEY,
      name   TEXT UNIQUE
    );
    CREATE TABLE IF NOT EXISTS game_tags (
      itad_id TEXT,
      tag_id  INTEGER,
      PRIMARY KEY (itad_id, tag_id),
      FOREIGN KEY (itad_id) REFERENCES games(itad_id) ON DELETE CASCADE,
      FOREIGN KEY (tag_id) REFERENCES tags(tag_id) ON DELETE CASCADE
    );

    CREATE TABLE IF NOT EXISTS reviews (
      itad_id TEXT,
      source  TEXT,
      score   INTEGER,
      count   INTEGER,
      url     TEXT,
      PRIMARY KEY (itad_id, source),
      FOREIGN KEY (itad_id) REFERENCES games(itad_id) ON DELETE CASCADE
    );

    CREATE TABLE IF NOT EXISTS players (
      itad_id TEXT PRIMARY KEY,
      recent  INTEGER,
      day     INTEGER,
      week    INTEGER,
      peak    INTEGER,
      FOREIGN KEY (itad_id) REFERENCES games(itad_id) ON DELETE CASCADE
    );

    CREATE INDEX IF NOT EXISTS idx_games_release ON games(release_date);
    """)
    conn.commit()

# %%
import pandas as pd

with closing(sqlite3.connect(DB_PATH)) as conn:
    pending = pd.read_sql("""
      SELECT s.itad_id
      FROM seeds s
      LEFT JOIN games g ON g.itad_id = s.itad_id
      WHERE s.status='mapped' AND s.itad_id IS NOT NULL AND g.itad_id IS NULL
    """, conn)['itad_id'].tolist()

len(pending), pending[:5]
# Out:
# (50003,
#  ['018d937f-2eb7-7037-82d1-2fab5fddf3d4',
#   '018d937f-1d1f-73fa-9019-5296f63a702f',
#   '018d937f-35ee-7204-ad6c-ae2e2639119f',
#   '018d937e-ffc5-7152-8d6f-33f59b72cdb4',
#   '018d937f-4ef3-7168-994d-7968084ab1a0'])

# %%
ITAD_API_KEY = os.getenv("ITAD_API_KEY")
assert ITAD_API_KEY, "Set ITAD_API_KEY in your environment!"

INFO_URL = "https://api.isthereanydeal.com/games/info/v2"

def fetch_info(itad_id, retry=3, sleep=1.0):
    params = {"key": ITAD_API_KEY, "id": itad_id}
    for attempt in range(1, retry+1):
        try:
            r = requests.get(INFO_URL, params=params, timeout=15)
            r.raise_for_status()
            return r.json()
        except requests.HTTPError as e:
            if r.status_code in (429, 500, 502, 503, 504):
                time.sleep(sleep * attempt)
                continue
            raise

# %%
def upsert_game(conn, info):
    # keep only 2021–2024 window and type == 'game'
    if info.get("type") != "game":
        return False
    rd = info.get("releaseDate")
    if not rd: 
        return False
    year = int(rd[:4])
    if year < 2021 or year > 2024:
        return False

    conn.execute("""
      INSERT INTO games (itad_id, appid, title, type, release_date, early_access, mature)
      VALUES (?, ?, ?, ?, ?, ?, ?)
      ON CONFLICT(itad_id) DO UPDATE SET
        appid=excluded.appid, title=excluded.title, type=excluded.type,
        release_date=excluded.release_date, early_access=excluded.early_access, mature=excluded.mature
    """, (
        info["id"],
        info.get("appid"),
        info.get("title"),
        info.get("type"),
        rd,
        int(bool(info.get("earlyAccess"))),
        int(bool(info.get("mature")))
    ))
    return True

def _id_for_name(conn, table, name_col, name_val):
    cur = conn.execute(f"INSERT OR IGNORE INTO {table} ({name_col}) VALUES (?);", (name_val,))
    # fetch id
    row = conn.execute(f"SELECT rowid AS id FROM {table} WHERE {name_col}=?;", (name_val,)).fetchone()
    return row[0]

def upsert_publishers(conn, itad_id, pubs):
    for p in pubs or []:
        pid = _id_for_name(conn, "publishers", "name", p.get("name"))
        conn.execute("INSERT OR IGNORE INTO game_publishers (itad_id, publisher_id) VALUES (?,?);", (itad_id, pid))

def upsert_developers(conn, itad_id, devs):
    for d in devs or []:
        did = _id_for_name(conn, "developers", "name", d.get("name"))
        conn.execute("INSERT OR IGNORE INTO game_developers (itad_id, developer_id) VALUES (?,?);", (itad_id, did))

def upsert_tags(conn, itad_id, tags):
    for t in tags or []:
        tid = _id_for_name(conn, "tags", "name", t)
        conn.execute("INSERT OR IGNORE INTO game_tags (itad_id, tag_id) VALUES (?,?);", (itad_id, tid))

def upsert_reviews(conn, itad_id, reviews):
    for r in reviews or []:
        conn.execute("""
          INSERT INTO reviews (itad_id, source, score, count, url)
          VALUES (?,?,?,?,?)
          ON CONFLICT(itad_id, source) DO UPDATE SET
            score=excluded.score, count=excluded.count, url=excluded.url
        """, (itad_id, r.get("source"), r.get("score"), r.get("count"), r.get("url")))

def upsert_players(conn, itad_id, players):
    if not players: 
        return
    conn.execute("""
      INSERT INTO players (itad_id, recent, day, week, peak)
      VALUES (?,?,?,?,?)
      ON CONFLICT(itad_id) DO UPDATE SET
        recent=excluded.recent, day=excluded.day, week=excluded.week, peak=excluded.peak
    """, (itad_id, players.get("recent"), players.get("day"), players.get("week"), players.get("peak")))

# %%
processed = 0
to_do = pending  # list from 2.1
BATCH_SLEEP = 0.6

with closing(sqlite3.connect(DB_PATH)) as conn:
    conn.execute("PRAGMA foreign_keys = ON;")
    for itad_id in to_do:
        info = fetch_info(itad_id)
        if not info:
            continue

        conn.execute("BEGIN;")
        inserted = upsert_game(conn, info)
        if inserted:
            upsert_publishers(conn, itad_id, info.get("publishers"))
            upsert_developers(conn, itad_id, info.get("developers"))
            upsert_tags(conn, itad_id, info.get("tags"))
            upsert_reviews(conn, itad_id, info.get("reviews"))
            upsert_players(conn, itad_id, info.get("players"))
        conn.commit()

        processed += 1
        if processed % 100 == 0:
            print(f"Processed {processed}/{len(to_do)}")
        time.sleep(BATCH_SLEEP)

print("Done:", processed)
# Out:
# Processed 100/50003
# Processed 200/50003
# Processed 300/50003
# Processed 400/50003
# Processed 500/50003
# Processed 600/50003
# Processed 700/50003
# Processed 800/50003
# Processed 900/50003
# Processed 1000/50003
# Processed 1100/50003
# Processed 1200/50003
# Processed 1300/50003
# Processed 1400/50003
# Processed 1500/50003
# Processed 1600/50003
# Processed 1700/50003
# Processed 1800/50003
# Processed 1900/50003
# Processed 2000/50003
# Processed 2100/50003
# Processed 2200/50003
# Processed 2300/50003
# Processed 2400/50003
# Processed 2500/50003
# Processed 2600/50003
# Processed 2700/50003
# Processed 2800/50003
# Processed 2900/50003
# Processed 3000/50003
# Processed 3100/50003
# Processed 3200/50003
# Processed 3300/50003
# Processed 3400/50003
# Processed 3500/50003
# Processed 3600/50003
# Processed 3700/50003
# Processed 3800/50003
# Processed 3900/50003
# Processed 4000/50003
# Processed 4100/50003
# Processed 4200/50003
# Processed 4300/50003
# ...

# %%
conn = sqlite3.connect("data/steam_sales.db")
pending = pd.read_sql("""
  SELECT s.itad_id
  FROM seeds s
  LEFT JOIN games g ON g.itad_id = s.itad_id
  WHERE s.status='mapped' AND s.itad_id IS NOT NULL AND g.itad_id IS NULL
""", conn)['itad_id'].tolist()
conn.close()
len(pending)
# Out:
# 7947

# %%
processed = 0
to_do = pending  # list from 2.1
BATCH_SLEEP = 0.6

with closing(sqlite3.connect(DB_PATH)) as conn:
    conn.execute("PRAGMA foreign_keys = ON;")
    for itad_id in to_do:
        info = fetch_info(itad_id)
        if not info:
            continue

        conn.execute("BEGIN;")
        inserted = upsert_game(conn, info)
        if inserted:
            upsert_publishers(conn, itad_id, info.get("publishers"))
            upsert_developers(conn, itad_id, info.get("developers"))
            upsert_tags(conn, itad_id, info.get("tags"))
            upsert_reviews(conn, itad_id, info.get("reviews"))
            upsert_players(conn, itad_id, info.get("players"))
        conn.commit()

        processed += 1
        if processed % 100 == 0:
            print(f"Processed {processed}/{len(to_do)}")
        time.sleep(BATCH_SLEEP)

print("Done:", processed)
# Out:
# Processed 100/7947
# Processed 200/7947
# Processed 300/7947
# Processed 400/7947
# Processed 500/7947
# Processed 600/7947
# Processed 700/7947
# Processed 800/7947
# Processed 900/7947
# Processed 1000/7947
# Processed 1100/7947
# Processed 1200/7947
# Processed 1300/7947
# Processed 1400/7947
# Processed 1500/7947
# Processed 1600/7947
# Processed 1700/7947
# Processed 1800/7947
# Processed 1900/7947
# Processed 2000/7947
# Processed 2100/7947
# Processed 2200/7947
# Processed 2300/7947
# Processed 2400/7947
# Processed 2500/7947
# Processed 2600/7947
# Processed 2700/7947
# Processed 2800/7947
# Processed 2900/7947
# Processed 3000/7947
# Processed 3100/7947
# Processed 3200/7947
# Processed 3300/7947
# Processed 3400/7947
# Processed 3500/7947
# Processed 3600/7947
# Processed 3700/7947
# Processed 3800/7947
# Processed 3900/7947
# Processed 4000/7947
# Processed 4100/7947
# Processed 4200/7947
# Processed 4300/7947
# Processed 4400/7947
# Processed 4500/7947
# ...

# %%
conn = sqlite3.connect("data/steam_sales.db")

pd.read_sql("SELECT * FROM games;", conn)
# Out:
#                                     itad_id      appid  \
# 0      018d937f-4ef3-7168-994d-7968084ab1a0   226280.0
# 1      018d937f-05cc-70d8-a9fd-b60cf6f8048e   226620.0
# 2      018d937e-f55f-735f-8a36-ef267cb911fe   251950.0
# 3      018d937f-1b52-72fe-8828-fc57d66141ae   252870.0
# 4      018d937f-4eeb-7084-878f-15fb7e4c22e9   269850.0
# ...                                     ...        ...
# 43135  01919e99-3f84-704f-9ba7-79afd7440a36  3186760.0
# 43136  01919c3d-0228-71d6-9a80-b61de4a3ee1b  3187770.0
# 43137  01919ce4-2521-719f-9fe8-966805c6ba80  3188750.0
# 43138  01919561-88ca-73f4-8123-1b114c928691  3188840.0
# 43139  0191aab8-da1b-7047-86be-bf0466fd99fc  3195690.0
#
#                               title  type release_date  early_access  mature
# 0                     Warp Frontier  game   2021-09-28             0       0
# 1                  Desktop Dungeons  game   2023-04-18             0       0
# ...

# %% [markdown]
# ### Building the price history database

# %%
DB_PATH = "data/steam_sales.db"
ITAD_API_KEY = os.getenv("ITAD_API_KEY")
assert ITAD_API_KEY, "Set ITAD_API_KEY in your environment!"
HIST_URL = "https://api.isthereanydeal.com/games/history/v2"
SHOP_STEAM = "61"
COUNTRY = "us"

# %%
with closing(sqlite3.connect(DB_PATH)) as conn:
    conn.executescript("""
    PRAGMA foreign_keys = ON;

    CREATE TABLE IF NOT EXISTS history_events (
      itad_id   TEXT,
      ts_utc    TEXT,   -- ISO8601 UTC '...Z'
      price     REAL,   -- discounted
      regular   REAL,   -- base/list price
      cut       INTEGER,
      PRIMARY KEY (itad_id, ts_utc)
    );

    CREATE INDEX IF NOT EXISTS idx_hist_itad_ts ON history_events(itad_id, ts_utc);
    """)
    conn.commit()

# %%
def iso_to_utc_z(ts: str) -> str:
    # Handles '...Z' or timezone offsets like '+02:00', returns UTC 'Z'
    dt = datetime.fromisoformat(ts.replace("Z", "+00:00")).astimezone(timezone.utc)
    return dt.replace(tzinfo=timezone.utc).isoformat().replace("+00:00", "Z")

def dedupe_keep_max_cut(events):
    # If multiple events share the same timestamp, keep the one with the highest 'cut'
    bucket = {}
    for e in events or []:
        t = e.get("timestamp")
        if not t:
            continue
        cur_cut = ((e.get("deal") or {}).get("cut") or 0)
        prev = bucket.get(t)
        if (prev is None) or (cur_cut > ((prev.get("deal") or {}).get("cut") or 0)):
            bucket[t] = e
    # return in chronological order
    return [bucket[t] for t in sorted(bucket.keys())]

def fetch_history(itad_id: str, release_date_iso: str, retry=3, sleep=1.0):
    params = {
        "key": ITAD_API_KEY,
        "id": itad_id,
        "shops": SHOP_STEAM,
        "country": COUNTRY,
        "since": f"{release_date_iso}T00:00:00Z",
    }
    for attempt in range(1, retry+1):
        r = requests.get(HIST_URL, params=params, timeout=20)
        try:
            r.raise_for_status()
            return r.json()  # list of events
        except requests.HTTPError:
            if r.status_code in (429, 500, 502, 503, 504):
                time.sleep(sleep * attempt)
                continue
            raise

def insert_history_rows(conn, itad_id: str, events):
    rows = []
    for e in events:
        deal = e.get("deal") or {}
        price = (deal.get("price") or {}).get("amount")
        regular = (deal.get("regular") or {}).get("amount")
        cut = deal.get("cut")
        ts = e.get("timestamp")
        if ts is None or price is None or regular is None or cut is None:
            continue
        rows.append((itad_id, iso_to_utc_z(ts), float(price), float(regular), int(cut)))
    if rows:
        conn.executemany("""
          INSERT OR REPLACE INTO history_events (itad_id, ts_utc, price, regular, cut)
          VALUES (?,?,?,?,?)
        """, rows)

# %%
with closing(sqlite3.connect(DB_PATH)) as conn:
    todo = pd.read_sql("""
      SELECT g.itad_id, g.release_date
      FROM games g
      WHERE g.release_date BETWEEN '2021-01-01' AND '2024-12-31'
        AND NOT EXISTS (
          SELECT 1 FROM history_events h WHERE h.itad_id = g.itad_id
        )
    """, conn)

len(todo), todo.head(3)
# Out:
# (43140,
#                                  itad_id release_date
#  0  018d937f-4650-70ba-a458-d52b46365f6e   2021-01-01
#  1  018d937f-4af3-7108-bc77-be5271928154   2021-01-01
#  2  018d937f-503e-73ce-9ddd-9e5e44744fbc   2021-01-01)

# %%
processed = 0
BATCH_SLEEP = 0.6  # ~1 req/sec

with closing(sqlite3.connect(DB_PATH)) as conn:
    conn.execute("PRAGMA foreign_keys = ON;")
    for itad_id, release_date_iso in todo.itertuples(index=False):
        try:
            events = fetch_history(itad_id, release_date_iso)
            events = dedupe_keep_max_cut(events)
            conn.execute("BEGIN;")
            insert_history_rows(conn, itad_id, events)
            conn.commit()
        except Exception as e:
            conn.rollback()
            # Optional: log errors to a table or print
            print(f"Error {itad_id}: {e}")
        processed += 1
        if processed % 200 == 0:
            print(f"Processed {processed}/{len(todo)}")
        time.sleep(BATCH_SLEEP)

print("Done:", processed)
# Out:
# Processed 200/43140
# Processed 400/43140
# Processed 600/43140
# Processed 800/43140
# Processed 1000/43140
# Processed 1200/43140
# Processed 1400/43140
# Processed 1600/43140
# Processed 1800/43140
# Processed 2000/43140
# Processed 2200/43140
# Processed 2400/43140
# Processed 2600/43140
# Processed 2800/43140
# Processed 3000/43140
# Processed 3200/43140
# Processed 3400/43140
# Processed 3600/43140
# Processed 3800/43140
# Processed 4000/43140
# Processed 4200/43140
# Processed 4400/43140
# Processed 4600/43140
# Processed 4800/43140
# Processed 5000/43140
# Processed 5200/43140
# Processed 5400/43140
# Processed 5600/43140
# Processed 5800/43140
# Processed 6000/43140
# Processed 6200/43140
# Processed 6400/43140
# Processed 6600/43140
# Processed 6800/43140
# Processed 7000/43140
# Processed 7200/43140
# Processed 7400/43140
# Processed 7600/43140
# Processed 7800/43140
# Processed 8000/43140
# Processed 8200/43140
# Processed 8400/43140
# Processed 8600/43140
# ...

# %%
df_final = pd.read_csv("/Users/farazahmed/Documents/GitHub/steam-discount-forecast/model_data/steam_games_updated.csv")
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30947 entries, 0 to 30946
# Data columns (total 46 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   itad_id                                30947 non-null  object
#  1   appid                                  30947 non-null  float64
#  2   title                                  30947 non-null  object
#  3   release_date                           30947 non-null  object
#  4   early_access                           30947 non-null  int64
#  5   mature                                 30947 non-null  int64
#  6   launch_price                           30947 non-null  float64
#  7   days_to_first_sale                     30947 non-null  int64
#  8   Achievements                           30947 non-null  int64
#  9   Developers                             30947 non-null  object
# ...

# %%
# !pip install tqdm
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...

# %%
import os, re, time, json, math
import requests
import pandas as pd
import numpy as np
from tqdm import tqdm
from urllib.parse import quote
from datetime import datetime
import sqlite3
from contextlib import closing
from dotenv import load_dotenv

# ---- config ----
load_dotenv()
RAWG_KEY = os.getenv("RAWG_API_KEY")
assert RAWG_KEY, "Set RAWG_API_KEY in your .env"

DB_PATH = "data/steam_sale.db"          # adjust if needed
OUT_CSV = "data/rawg_platforms_dump.csv"

# Your dataset (must have columns: title, appid, release_date)
df_src = df_final.copy()
df_src = df_src[["title","appid","release_date"]].dropna(subset=["title"]).reset_index(drop=True)
df_src["appid"] = df_src["appid"].astype("Int64")  # keep NaNs as <NA>
df_src["release_date"] = pd.to_datetime(df_src["release_date"]).dt.date.astype(str)

# ---- small helpers ----
SLEEP = 0.35  # be gentle with the API
SES = requests.Session()
BASE = "https://api.rawg.io/api"

def _get(url, params=None, retries=3):
    params = params or {}
    params["key"] = RAWG_KEY
    for k in range(retries):
        try:
            r = SES.get(url, params=params, timeout=20)
            if r.status_code == 200:
                return r.json()
            # simple backoff
            time.sleep(1 + k)
        except requests.RequestException:
            time.sleep(1 + k)
    return None

STEAM_APPID_RE = re.compile(r"/app/(\d+)")

def search_game(title, page_size=5):
    """Search RAWG by exact-ish title."""
    data = _get(f"{BASE}/games", params={
        "search": title,
        "search_precise": "true",
        "page_size": page_size
    })
    return data.get("results", []) if data else []

def get_game_detail(rawg_id):
    return _get(f"{BASE}/games/{rawg_id}")

def pick_best_candidate(title, appid, results):
    """
    Heuristic:
      1) Prefer a result whose 'stores' include Steam with matching appid (via detail call).
      2) Else prefer the closest name (case-insensitive exact match first).
      3) Else top result.
    """
    title_norm = title.strip().lower()

    # try exact title match first
    exact = [r for r in results if r.get("name","").strip().lower()==title_norm]
    candidates = exact or results
    return candidates[0] if candidates else None

def extract_from_detail(detail, steam_appid_expected=None):
    """
    Return a normalized row of RAWG info:
      - rawg_id, rawg_slug, name, released
      - platforms (list of names), platform_slugs
      - stores (list of names), store_slugs
      - steam_appid_detected (from store URL, if present)
      - per-platform released_at when available
    """
    if not detail: 
        return None
    rawg_id   = detail.get("id")
    slug      = detail.get("slug")
    name      = detail.get("name")
    released  = detail.get("released")  # YYYY-MM-DD or None

    # platforms
    plats = detail.get("platforms") or []
    platform_names = []
    platform_slugs = []
    platform_dates = []
    for p in plats:
        plat = p.get("platform") or {}
        platform_names.append(plat.get("name"))
        platform_slugs.append(plat.get("slug"))
        platform_dates.append(p.get("released_at"))  # may be None

    # stores (to detect Steam appid if present)
    stores = detail.get("stores") or []
    store_names = []
    store_slugs = []
    steam_appid_detected = None
    for s in stores:
        st = s.get("store") or {}
        store_names.append(st.get("name"))
        store_slugs.append(st.get("slug"))
        url = s.get("url_en") or s.get("url") or ""
        m = STEAM_APPID_RE.search(url)
        if m:
            steam_appid_detected = int(m.group(1))

    # compact
    return {
        "rawg_id": rawg_id,
        "rawg_slug": slug,
        "rawg_name": name,
        "rawg_released": released,
        "platform_names": json.dumps(platform_names, ensure_ascii=False),
        "platform_slugs": json.dumps(platform_slugs, ensure_ascii=False),
        "platform_released_at": json.dumps(platform_dates, ensure_ascii=False),
        "store_names": json.dumps(store_names, ensure_ascii=False),
        "store_slugs": json.dumps(store_slugs, ensure_ascii=False),
        "steam_appid_detected": steam_appid_detected,
    }

rows = []
seen = set()

for i, row in tqdm(df_src.iterrows(), total=len(df_src)):
    title = str(row["title"])
    appid = int(row["appid"]) if not pd.isna(row["appid"]) else None
    key = (title.lower(), appid)
    if key in seen:
        continue
    seen.add(key)

    results = search_game(title)
    if not results:
        rows.append({
            "title": title, "appid": appid, "steam_release_date": row["release_date"],
            "match_status": "no_results"
        })
        time.sleep(SLEEP); continue

    # pick candidate
    c = pick_best_candidate(title, appid, results)
    detail = get_game_detail(c["id"]) if c else None
    if not detail:
        rows.append({
            "title": title, "appid": appid, "steam_release_date": row["release_date"],
            "match_status": "detail_failed"
        })
        time.sleep(SLEEP); continue

    info = extract_from_detail(detail, appid)
    match_ok = "ok"
    # (optional) if you want to enforce appid match when available:
    if appid is not None and info.get("steam_appid_detected") not in (None, appid):
        match_ok = "appid_mismatch"

    rows.append({
        "title": title,
        "appid": appid,
        "steam_release_date": row["release_date"],
        "match_status": match_ok,
        **info
    })

    time.sleep(SLEEP)

df_rawg = pd.DataFrame(rows)
df_rawg.to_csv(OUT_CSV, index=False)
df_rawg.head()
# Out:
# 100%|██████████| 30947/30947 [40:58:21<00:00,  4.77s/it]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 174
#     171     time.sleep(SLEEP)
#     173 df_rawg = pd.DataFrame(rows)
# --> 174 df_rawg.to_csv(OUT_CSV, index=False)
#     175 df_rawg.head()
#
# File ~/Documents/GitHub/steam-discount-forecast/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df_rawg.head()
# Out:
#                                  title    appid steam_release_date  \
# 0  Silent Night - A Christmas Delivery  1630740         2021-01-01
# 1                    Bad boy simulator  1489380         2021-01-02
# 2                         Zombie Alert  1496710         2021-01-02
# 3                   Tower Defense Hero  1489330         2021-01-02
# 4                     Infinite Gateway   713800         2021-01-03
#
#   match_status   rawg_id                          rawg_slug  \
# 0           ok  702285.0  silent-night-a-christmas-delivery
# 1           ok  536912.0                  bad-boy-simulator
# 2           ok  539050.0                       zombie-alert
# 3           ok  539052.0                 tower-defense-hero
# 4           ok   46743.0                   infinite-gateway
#
#                              rawg_name rawg_released   platform_names  \
# 0  Silent Night - A Christmas Delivery    2021-12-01           ["PC"]
# ...

# %%
df_rawg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30947 entries, 0 to 30946
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 30947 non-null  object
#  1   appid                 30947 non-null  int64
#  2   steam_release_date    30947 non-null  object
#  3   match_status          30947 non-null  object
#  4   rawg_id               10220 non-null  float64
#  5   rawg_slug             10220 non-null  object
#  6   rawg_name             10220 non-null  object
#  7   rawg_released         9628 non-null   object
#  8   platform_names        10220 non-null  object
#  9   platform_slugs        10220 non-null  object
#  10  platform_released_at  10220 non-null  object
#  11  store_names           10220 non-null  object
#  12  store_slugs           10220 non-null  object
#  13  steam_appid_detected  0 non-null      float64
# dtypes: float64(2), int64(1), object(11)
# ...

# %%
df_rawg['store_names'].value_counts()
# Out:
# store_names
# ["Steam"]                                                                                         8416
# ["Steam", "itch.io"]                                                                               333
# ["GOG", "Steam"]                                                                                   212
# ["itch.io", "Steam"]                                                                               173
# ["itch.io"]                                                                                        120
#                                                                                                   ...
# ["GOG", "Xbox Store", "Steam", "Epic Games"]                                                         1
# ["Epic Games", "Xbox Store", "Steam"]                                                                1
# ["Nintendo Store", "App Store", "GOG", "Steam", "Epic Games"]                                        1
# ...

# %%
df_rawg.to_csv('/Users/farazahmed/Documents/GitHub/steam-discount-forecast/model_data/rawg_platforms_dump.csv', index=False)

# %%
import os, re, time, json, hashlib, threading, queue
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from dotenv import load_dotenv
from pathlib import Path

# --------------------
# Config
# --------------------
load_dotenv()
RAWG_KEY = os.getenv("RAWG_API_KEY")
assert RAWG_KEY, "Set RAWG_API_KEY in your .env"

BASE_URL    = "https://api.rawg.io/api"
OUT_CSV     = "data/rawg_platforms_dump.csv"   # append/resume here
CACHE_DIR   = Path("data/.rawg_cache")         # local GET cache (json)
MAX_WORKERS = 4                                 # parallel threads (tune)
RPS         = 3                                 # requests per second budget (tune)

CACHE_DIR.mkdir(parents=True, exist_ok=True)
STEAM_APPID_RE = re.compile(r"/app/(\d+)")

# --------------------
# Helper: tiny GET cache
# --------------------
def _cache_key(url, params):
    key_src = url + "?" + "&".join(sorted(f"{k}={params[k]}" for k in params))
    return CACHE_DIR / (hashlib.sha1(key_src.encode("utf-8")).hexdigest() + ".json")

def cached_get(url, params, timeout=20):
    """Disk-cached GET. If not cached, hits RAWG and stores JSON."""
    params = dict(params or {})
    params["key"] = RAWG_KEY
    ck = _cache_key(url, params)
    if ck.exists():
        try:
            return json.loads(ck.read_text(encoding="utf-8"))
        except Exception:
            ck.unlink(missing_ok=True)  # bad cache; retry network

    r = requests.get(url, params=params, timeout=timeout)
    if r.status_code == 200:
        data = r.json()
        ck.write_text(json.dumps(data), encoding="utf-8")
        return data
    return None

# --------------------
# Helper: rate limiter (token bucket-ish)
# --------------------
_lock = threading.Lock()
_last = []

def rate_limit():
    """Allow ~RPS across all threads."""
    with _lock:
        now = time.time()
        # purge timestamps older than 1s
        while _last and now - _last[0] > 1.0:
            _last.pop(0)
        if len(_last) >= RPS:
            sleep_for = 1.0 - (now - _last[0])
        else:
            sleep_for = 0.0
        if sleep_for > 0:
            time.sleep(sleep_for)
        _last.append(time.time())

# --------------------
# RAWG calls
# --------------------
def search_game(title):
    rate_limit()
    return cached_get(f"{BASE_URL}/games", {
        "search": title,
        "search_precise": "true",
        "page_size": 5
    }) or {}

def get_game_detail(rawg_id):
    rate_limit()
    return cached_get(f"{BASE_URL}/games/{rawg_id}", {}) or {}

def pick_best_candidate(title, results):
    """Prefer exact (case-insensitive) name match; else top result."""
    title_norm = (title or "").strip().lower()
    items = results.get("results", []) if isinstance(results, dict) else results
    exact = [r for r in items if (r.get("name","").strip().lower() == title_norm)]
    candidates = exact or items
    return candidates[0] if candidates else None

def extract_from_detail(detail):
    if not detail:
        return None
    plats = detail.get("platforms") or []
    stores = detail.get("stores") or []

    platform_names, platform_slugs, platform_dates = [], [], []
    for p in plats:
        pp = p.get("platform") or {}
        platform_names.append(pp.get("name"))
        platform_slugs.append(pp.get("slug"))
        platform_dates.append(p.get("released_at"))

    store_names, store_slugs = [], []
    steam_appid_detected = None
    for s in stores:
        st = s.get("store") or {}
        store_names.append(st.get("name"))
        store_slugs.append(st.get("slug"))
        url = s.get("url_en") or s.get("url") or ""
        m = STEAM_APPID_RE.search(url)
        if m:
            try:
                steam_appid_detected = int(m.group(1))
            except:
                pass

    return {
        "rawg_id": detail.get("id"),
        "rawg_slug": detail.get("slug"),
        "rawg_name": detail.get("name"),
        "rawg_released": detail.get("released"),
        "platform_names": json.dumps(platform_names, ensure_ascii=False),
        "platform_slugs": json.dumps(platform_slugs, ensure_ascii=False),
        "platform_released_at": json.dumps(platform_dates, ensure_ascii=False),
        "store_names": json.dumps(store_names, ensure_ascii=False),
        "store_slugs": json.dumps(store_slugs, ensure_ascii=False),
        "steam_appid_detected": steam_appid_detected,
    }

# --------------------
# Build the worklist FROM df_rawg (your existing dump)
# --------------------
# df_rawg must already be in memory with the columns you showed.
# We will re-hit only rows that have no platform_slugs or store_slugs.

df_src = df_rawg[["title", "appid", "steam_release_date",
                  "platform_slugs", "store_slugs", "rawg_id", "match_status"]].copy()

# rows still missing platform/store info
missing_mask = df_src["platform_slugs"].isna() | df_src["store_slugs"].isna()

# (optional) also retry rows where previous match failed
# e.g., match_status in {"no_results","detail_failed","appid_mismatch"}
retry_bad = df_src["match_status"].isin(["no_results", "detail_failed", "appid_mismatch"])

work = df_src.loc[missing_mask | retry_bad, ["title", "appid", "steam_release_date"]].dropna(subset=["title"]).reset_index(drop=True)

# make sure appid is numeric (some pandas dtypes can be object)
work["appid"] = pd.to_numeric(work["appid"], errors="coerce").astype("Int64")

# Resume support: skip (title, appid) already present in OUT_CSV
already = set()
if os.path.exists(OUT_CSV):
    prev = pd.read_csv(OUT_CSV, dtype={"appid":"Int64"})
    for _, r in prev[["title","appid"]].drop_duplicates().iterrows():
        already.add((str(r["title"]).strip().lower(),
                     int(r["appid"]) if pd.notna(r["appid"]) else None))

work = work[~work.apply(lambda r: (str(r["title"]).strip().lower(),
                                   int(r["appid"]) if pd.notna(r["appid"]) else None) in already, axis=1)].reset_index(drop=True)

print(f"To fetch: {len(work)} rows")

# --------------------
# Worker
# --------------------
def process_row(row):
    title = str(row["title"])
    appid = int(row["appid"]) if pd.notna(row["appid"]) else None

    sr = search_game(title)
    cand = pick_best_candidate(title, sr)
    if not cand:
        return {
            "title": title, "appid": appid, "steam_release_date": row["release_date"],
            "match_status": "no_results"
        }

    detail = get_game_detail(cand.get("id"))
    if not detail:
        return {
            "title": title, "appid": appid, "steam_release_date": row["release_date"],
            "match_status": "detail_failed"
        }

    info = extract_from_detail(detail) or {}
    match_ok = "ok"
    # if you want to enforce appid match when RAWG exposes it via store url:
    if appid is not None and info.get("steam_appid_detected") not in (None, appid):
        match_ok = "appid_mismatch"

    return {
        "title": title,
        "appid": appid,
        "steam_release_date": row["steam_release_date"],  # <— use steam_release_date here
        "match_status": match_ok,
        **info
    }

# --------------------
# Run (parallel + periodic flush)
# --------------------
results, buffer = [], []
FLUSH_EVERY = 200

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
    futs = {ex.submit(process_row, r): i for i, r in work.iterrows()}
    for n, fut in enumerate(as_completed(futs), 1):
        try:
            buffer.append(fut.result())
        except Exception as e:
            # defensive: keep going
            buffer.append({"title": None, "appid": None, "steam_release_date": None,
                           "match_status": f"exception:{e}"})
        if len(buffer) >= FLUSH_EVERY:
            pd.DataFrame(buffer).to_csv(OUT_CSV, mode=("a" if os.path.exists(OUT_CSV) else "w"),
                                        header=not os.path.exists(OUT_CSV), index=False)
            buffer.clear()
    # final flush
    if buffer:
        pd.DataFrame(buffer).to_csv(OUT_CSV, mode=("a" if os.path.exists(OUT_CSV) else "w"),
                                    header=not os.path.exists(OUT_CSV), index=False)

print("Done.")
# Out:
# To fetch: 20727 rows
# Done.

# %%
df3 = pd.read_csv("/Users/farazahmed/Documents/GitHub/steam-discount-forecast/notebooks/data/rawg_platforms_dump.csv")
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20727 entries, 0 to 20726
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               0 non-null      float64
#  1   appid               0 non-null      float64
#  2   steam_release_date  0 non-null      float64
#  3   match_status        20727 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 647.8+ KB

# %%
df3.head()
# Out:
#    title  appid  steam_release_date              match_status
# 0    NaN    NaN                 NaN  exception:'release_date'
# 1    NaN    NaN                 NaN  exception:'release_date'
# 2    NaN    NaN                 NaN  exception:'release_date'
# 3    NaN    NaN                 NaN  exception:'release_date'
# 4    NaN    NaN                 NaN  exception:'release_date'

# %%
# !pip install aiohttp
# Out:
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [aiohttp]
# ...

# %%
# !pip install nest_asyncio aiohttp

# %%
# --- Setup ---
import os, json, asyncio, aiohttp, time
import pandas as pd
import numpy as np
from tqdm.auto import tqdm


RAWG_KEY = os.getenv("RAWG_API_KEY")
assert RAWG_KEY, "Set RAWG_API_KEY in your environment (e.g., in .env)"

IN_CSV  = "/Users/farazahmed/Documents/GitHub/steam-discount-forecast/model_data/rawg_platforms_dump.csv"
OUT_CSV = "/Users/farazahmed/Documents/GitHub/steam-discount-forecast/model_data/rawg_platforms_dump_refreshed.csv"

BASE = "https://api.rawg.io/api"
SEARCH_PARAMS = {"search_precise": "true", "page_size": 5}

# --- Load existing dump ---
df_rawg = pd.read_csv(IN_CSV)
ALL_COLS = list(df_rawg.columns)  # ensure we keep identical schema/order

def _as_list_or_none(val):
    if pd.isna(val):
        return None
    if isinstance(val, list):
        return val
    s = str(val).strip()
    if s in ("", "nan", "None", "[]"):
        return None
    try:
        return json.loads(s)
    except Exception:
        return None

platform_missing = df_rawg["platform_slugs"].apply(_as_list_or_none).isna()
store_missing    = df_rawg["store_slugs"].apply(_as_list_or_none).isna()
needs_retry = (df_rawg["match_status"] != "ok") | platform_missing | store_missing

to_fix = df_rawg[needs_retry].copy()
ok_old = df_rawg[~needs_retry].copy()

print(f"Total rows: {len(df_rawg)}")
print(f"Already OK: {len(ok_old)}")
print(f"To (re)try: {len(to_fix)}")

# --- Helpers ---
def title_key(s: str) -> str:
    return (s or "").strip().lower()

def pick_best_candidate(title, results):
    tkey = title_key(title)
    exact = [r for r in results if title_key(r.get("name","")) == tkey]
    return exact[0] if exact else (results[0] if results else None)

def extract_detail_payload(detail: dict):
    if not detail:
        return None
    plats  = detail.get("platforms") or []
    stores = detail.get("stores") or []

    platform_names = [ (p.get("platform") or {}).get("name") for p in plats ]
    platform_slugs = [ (p.get("platform") or {}).get("slug") for p in plats ]
    platform_dates = [ p.get("released_at") for p in plats ]

    store_names = [ (s.get("store") or {}).get("name") for s in stores ]
    store_slugs = [ (s.get("store") or {}).get("slug") for s in stores ]

    return {
        "rawg_id"      : detail.get("id"),
        "rawg_slug"    : detail.get("slug"),
        "rawg_name"    : detail.get("name"),
        "rawg_released": detail.get("released"),
        "platform_names": json.dumps(platform_names, ensure_ascii=False),
        "platform_slugs": json.dumps(platform_slugs, ensure_ascii=False),
        "platform_released_at": json.dumps(platform_dates, ensure_ascii=False),
        "store_names": json.dumps(store_names, ensure_ascii=False),
        "store_slugs": json.dumps(store_slugs, ensure_ascii=False),
    }

# --- Async RAWG client with retries/throttle + progress log ---
SEM_LIMIT = 10
RETRIES   = 3
TIMEOUT_S = 25
LOG_EVERY = 500  # progress log granularity

async def _get_json(session, url, params=None):
    params = dict(params or {})
    params["key"] = RAWG_KEY
    for attempt in range(RETRIES):
        try:
            async with session.get(url, params=params, timeout=TIMEOUT_S) as resp:
                if resp.status == 200:
                    return await resp.json()
                await asyncio.sleep(1 + attempt)
        except Exception:
            await asyncio.sleep(1 + attempt)
    return None

async def fetch_one(session, sem, title, appid, steam_release_date):
    row = {
        "title": title, "appid": appid,
        "steam_release_date": steam_release_date,
        "match_status": "no_results",
        "rawg_id": np.nan, "rawg_slug": np.nan, "rawg_name": np.nan,
        "rawg_released": np.nan,
        "platform_names": np.nan, "platform_slugs": np.nan, "platform_released_at": np.nan,
        "store_names": np.nan, "store_slugs": np.nan
    }
    async with sem:
        data = await _get_json(session, f"{BASE}/games", params={**SEARCH_PARAMS, "search": title})
        results = (data or {}).get("results", [])
        cand = pick_best_candidate(title, results)
        if not cand:
            return row

        detail = await _get_json(session, f"{BASE}/games/{cand['id']}")
        if not detail:
            row["match_status"] = "detail_failed"
            return row

        payload = extract_detail_payload(detail)
        if not payload:
            row["match_status"] = "detail_failed"
            return row

        row.update(payload)
        row["match_status"] = "ok"
        return row

async def run_batch(to_fix_df: pd.DataFrame):
    tasks, sem = [], asyncio.Semaphore(SEM_LIMIT)
    conn = aiohttp.TCPConnector(limit_per_host=SEM_LIMIT)
    async with aiohttp.ClientSession(connector=conn) as session:
        for _, r in to_fix_df.iterrows():
            tasks.append(fetch_one(session, sem, str(r["title"]), int(r["appid"]), str(r["steam_release_date"])))
        results = []
        start = time.time()
        ok_so_far = 0
        for i, fut in enumerate(tqdm(asyncio.as_completed(tasks), total=len(tasks))):
            res = await fut
            results.append(res)
            if res.get("match_status") == "ok":
                ok_so_far += 1
            if (i + 1) % LOG_EVERY == 0 or (i + 1) == len(tasks):
                elapsed = time.time() - start
                rps = (i + 1) / elapsed if elapsed > 0 else 0.0
                print(f"[Progress] {i+1}/{len(tasks)} done | {rps:.2f} rows/sec | ok so far: {ok_so_far/(i+1):.1%}")
        return pd.DataFrame(results)

# --- Kick off async fetch only for rows that need it (Jupyter-safe) ---
if len(to_fix):
    import aiohttp, nest_asyncio, asyncio
    nest_asyncio.apply()  # allow nested event loops in notebooks

    loop = asyncio.get_event_loop()
    df_new = loop.run_until_complete(
        run_batch(to_fix[["title","appid","steam_release_date"]])
    )
else:
    df_new = pd.DataFrame(columns=["title","appid","steam_release_date","match_status"])

print("New rows fetched:", len(df_new))

# Ensure df_new has **exactly** the same columns as original
for col in ALL_COLS:
    if col not in df_new.columns:
        df_new[col] = np.nan
df_new = df_new[ALL_COLS]  # reorder

# Prefer new rows for retried keys, keep original OK rows for others
def pref_ok(group):
    # prefer 'ok', otherwise keep first
    g = group.sort_values(by="match_status", key=lambda s: (s!="ok").astype(int))
    return g.iloc[0]

df_merged = pd.concat([ok_old, df_new], ignore_index=True)
df_merged = (
    df_merged
    .sort_values(["title","appid","match_status"])
    .groupby(["title","appid"], as_index=False, group_keys=False)
    .apply(pref_ok)
    .reset_index(drop=True)
)

print(df_merged["match_status"].value_counts(dropna=False))

# --- Add is_multiplatform ---
CONSOLE_SLUGS = {
    "playstation", "ps5", "ps4", "ps3",
    "xbox-one", "xbox-series-x", "xbox360", "xbox-series-s-x", "xbox",
    "nintendo-switch", "wii-u", "wii", "3ds", "2ds"
}

def is_multi(platform_slugs, store_slugs):
    plats = _as_list_or_none(platform_slugs) or []
    stores = _as_list_or_none(store_slugs) or []
    has_console = any(any(slug.startswith(cs) for cs in CONSOLE_SLUGS) for slug in plats)
    has_nonsteam_store = any(s and str(s).lower() != "steam" for s in stores)
    return bool(has_console or has_nonsteam_store)

df_merged["is_multiplatform"] = df_merged.apply(
    lambda r: is_multi(r["platform_slugs"], r["store_slugs"]), axis=1
)

# --- Save ---
df_merged.to_csv(OUT_CSV, index=False)
print("Wrote:", OUT_CSV)

share_ok = (df_merged["match_status"] == "ok").mean()
print(f"OK ratio after refresh: {share_ok:.1%}")
print(df_merged[["match_status","is_multiplatform"]].value_counts().head(10))
# Out:
# Total rows: 30947
# Already OK: 10168
# To (re)try: 20779
#   2%|▏         | 500/20779 [05:19<3:18:31,  1.70it/s]
# [Progress] 500/20779 done | 1.56 rows/sec | ok so far: 0.0%
#   5%|▍         | 1000/20779 [10:41<4:39:41,  1.18it/s]
# [Progress] 1000/20779 done | 1.56 rows/sec | ok so far: 0.0%
#   7%|▋         | 1498/20779 [15:57<4:22:18,  1.23it/s]
# [Progress] 1500/20779 done | 1.57 rows/sec | ok so far: 0.0%
#  10%|▉         | 1999/20779 [21:21<4:37:59,  1.13it/s]
# [Progress] 2000/20779 done | 1.56 rows/sec | ok so far: 0.0%
#  12%|█▏        | 2503/20779 [26:40<2:10:21,  2.34it/s]
# [Progress] 2500/20779 done | 1.56 rows/sec | ok so far: 0.0%
#  14%|█▍        | 3000/20779 [31:56<2:34:24,  1.92it/s]
# [Progress] 3000/20779 done | 1.56 rows/sec | ok so far: 0.0%
#  17%|█▋        | 3500/20779 [37:10<3:15:53,  1.47it/s]
# [Progress] 3500/20779 done | 1.57 rows/sec | ok so far: 0.0%
#  19%|█▉        | 4000/20779 [42:24<4:14:28,  1.10it/s]
# ...

# %%
# !pip install pandas openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...

# %%
import os
import sqlite3
import pandas as pd

# ---- settings ----
DB_PATH = "/Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/steam_sales.db"
OUT_DIR_NAME = "Excel files"     # folder to hold the Excel outputs
# ------------------

def main():
    db_dir = os.path.dirname(DB_PATH)
    out_dir = os.path.join(db_dir, OUT_DIR_NAME)
    os.makedirs(out_dir, exist_ok=True)

    conn = sqlite3.connect(DB_PATH)
    try:
        # get only *tables* (skip sqlite internal tables)
        tables = pd.read_sql(
            "SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%' ORDER BY name;",
            conn
        )["name"].tolist()

        if not tables:
            print("No user tables found.")
            return

        for t in tables:
            df = pd.read_sql(f"SELECT * FROM [{t}];", conn)
            # safe filename
            filename = f"{t}.xlsx"
            filepath = os.path.join(out_dir, filename)

            # write to Excel (openpyxl is default writer for .xlsx via pandas)
            with pd.ExcelWriter(filepath, engine="openpyxl") as writer:
                df.to_excel(writer, index=False, sheet_name=t[:31])  # Excel sheet name max length 31
            print(f"✔ Exported {t} -> {filepath}")

        print(f"\nAll done. Files are in: {out_dir}")

    finally:
        conn.close()

if __name__ == "__main__":
    main()
# Out:
# ✔ Exported developers -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/developers.xlsx
# ✔ Exported game_developers -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/game_developers.xlsx
# ✔ Exported game_publishers -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/game_publishers.xlsx
# ✔ Exported game_tags -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/game_tags.xlsx
# ✔ Exported games -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/games.xlsx
# ✔ Exported history_events -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/history_events.xlsx
# ✔ Exported players -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/players.xlsx
# ✔ Exported publishers -> /Users/farazahmed/Documents/GitHub/steam-discount-forecast/data/Excel files/publishers.xlsx
# ...
